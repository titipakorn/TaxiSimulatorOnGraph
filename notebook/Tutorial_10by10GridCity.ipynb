# %% [markdown]
# # Simple 10 by 10 Grid Case
# This notebook gives a brief overview on how to run simulation on simple grid shaped road network.

# %% [markdown]
#  First generate road network graph G and visualize it.

# %%
import warnings
warnings.filterwarnings('ignore')
# %load_ext autoreload
# %autoreload 2
import sys 
sys.path.append("../")
from graph_utils import *
G = generate_square_multidi_graph(10,10, mean_distance=400, std=100)
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /home/users/u6022040726/miniconda3/envs/roadnetwork/share/proj failed

# %%
import matplotlib.pyplot as plt
nx.draw(G)
plt.draw()

# %% [markdown]
# Because above graph G is networkx Graph object, we need to convert it to dgl(deep graph library) Graph object. After conversion, let's transform the graph into its line graph.

# %%
import dgl
g = dgl.from_networkx(G, edge_attrs=['length', 'u', 'v'])
g_line = g.line_graph(shared=True)

# %% [markdown]
# Now let's train and evaluate on this road network. We will use four models as the papar(random, proportional, GCN_DQN, GAT_DQN).
# We will also test for different $\beta$s (policy_pows).

# %%
from main import *
from call_generator import RandomCallGenerator
from driver_initializer import *
import time

TEST_EPOCH = 5
TRAIN_EPOCH = 5
TEST_TIME_STEPS = 10
TRAIN_TIME_STEPS = 10

call_coeffs = [0.7] #how many calls
# policy_pows = [0.1, 0.5, 1.0, 1.5, 2.0, 3.0, 1000.0]
policy_pows = [0.1, 0.5]

# %%
# Create file to export result log.
save_folder = 'hyper_param_tests_on_simple_case'
if not os.path.exists(save_folder):
    os.makedirs(save_folder)

started_time_date = time.strftime("%Y%m%d_%H%M%S")
f = open("%s/total_results_with_speed_%s.txt" % (save_folder, started_time_date), 'w')
f.write('call_percentage\tname\tmean\tstd\n')
f.flush()

def eval_and_write(city, agent, call_coeff):
    m, s = evaluate(city, agent, epochs = TEST_EPOCH, time_steps=TEST_TIME_STEPS, export_result=False, verbose=False)
    f.write('%.2f\t%s\t%.4f\t%.4f\n' % (call_coeff, agent.name, m, s))
    f.flush()

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0"
for call_coeff in call_coeffs:
    driver_initializer = RandomDriverInitializer(driver_n = [0, 1], driver_p = [0.2, 0.8])
    call_generator = RandomCallGenerator(coeff=call_coeff, wait_mean=5, duration_mean=12)
    city = City(g_line, call_generator, driver_initializer, consider_speed=True)

    # (1) Random
    eval_and_write(city, RandomAgent(), call_coeff)

    # for policy_pow in policy_pows:
    #     # if power is too large it is regarded as a greedy update.
    #     strategy = POLICY_ARGMAX if policy_pow > 500 else POLICY_POW
    #     print("startegy!")
    #     # (2) Proportional to order
    #     print("proportional agent!")
    #     proportional_agent = ProportionalAgent(city, proportional='order', policy_pow=policy_pow,strategy=strategy)
    #     eval_and_write(city, proportional_agent, call_coeff)
    #     # # (3) GCN-DQN
    #     print("GCN-DQN")
    #     dqn_agent_gcn = DQNAgent(city, model_type='gcn', policy_pow=policy_pow,strategy=strategy)
    #     train(city, dqn_agent_gcn, epochs = TRAIN_EPOCH, time_steps=TRAIN_TIME_STEPS, verbose=False)
    #     with torch.no_grad():
    #         eval_and_write(city, dqn_agent_gcn, call_coeff)
    #     # # (4) GAT-DQN
    #     dqn_agent_gat = DQNAgent(city, model_type='gat', policy_pow=policy_pow,strategy=strategy)
    #     train(city, dqn_agent_gat, epochs = TRAIN_EPOCH, time_steps=TRAIN_TIME_STEPS, verbose=False)
    #     with torch.no_grad():
    #         eval_and_write(city, dqn_agent_gat, call_coeff)
# Out:
# City initialized with total 284 drivers
# Epsilon set to 0.0
# Order response rate in this episode: 0.6298076923076923
# City initialized with total 286 drivers
# Epsilon set to 0.0
# Order response rate in this episode: 0.7555555555555555
# City initialized with total 289 drivers
# Epsilon set to 0.0
# Order response rate in this episode: 0.7068062827225131
# City initialized with total 286 drivers
# Epsilon set to 0.0
# Order response rate in this episode: 0.6615384615384615
# City initialized with total 286 drivers
# Epsilon set to 0.0
# Order response rate in this episode: 0.6813725490196079
# 00:00:01
# Total percentage: 0.6850715746421268
# Total percentage 2: 0.687016108228766 0.047547528694918864
# startegy!
# proportional agent!
# City initialized with total 284 drivers
# Epsilon set to 0.0
# Order response rate in this episode: 0.8136363636363636
# City initialized with total 286 drivers
# Epsilon set to 0.0
# Order response rate in this episode: 0.898936170212766
# City initialized with total 289 drivers
# Epsilon set to 0.0
# Order response rate in this episode: 0.8585858585858586
# City initialized with total 286 drivers
# Epsilon set to 0.0
# Order response rate in this episode: 0.8660287081339713
# City initialized with total 286 drivers
# Epsilon set to 0.0
# Order response rate in this episode: 0.8269230769230769
# 00:00:04
# Total percentage: 0.8514173998044966
# Total percentage 2: 0.8528220354984073 0.0336913349902718
# GCN-DQN
# City initialized with total 284 drivers
# output of QVALUES 360
# out_nodes [2, 3, 4]
# output of possible_action_values tensor([0.4371, 0.4369, 0.4363], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [28, 29, 30]
# output of possible_action_values tensor([0.4371, 0.4363, 0.4368], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [0, 1]
# output of possible_action_values tensor([0.4331, 0.4333], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [5, 6, 7]
# output of possible_action_values tensor([0.4366, 0.4385, 0.4367], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [31, 32, 33, 34]
# output of possible_action_values tensor([0.4388, 0.4387, 0.4385, 0.4383], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [2, 3, 4]
# output of possible_action_values tensor([0.4371, 0.4369, 0.4363], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [8, 9, 10]
# output of possible_action_values tensor([0.4369, 0.4405, 0.4375], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [35, 36, 37, 38]
# output of possible_action_values tensor([0.4382, 0.4390, 0.4394, 0.4381], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [5, 6, 7]
# output of possible_action_values tensor([0.4366, 0.4385, 0.4367], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [11, 12, 13]
# output of possible_action_values tensor([0.4385, 0.4430, 0.4395], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [39, 40, 41, 42]
# output of possible_action_values tensor([0.4385, 0.4406, 0.4413, 0.4389], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [8, 9, 10]
# output of possible_action_values tensor([0.4369, 0.4405, 0.4375], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [14, 15, 16]
# output of possible_action_values tensor([0.4405, 0.4429, 0.4411], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [43, 44, 45, 46]
# output of possible_action_values tensor([0.4394, 0.4425, 0.4428, 0.4395], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [11, 12, 13]
# output of possible_action_values tensor([0.4385, 0.4430, 0.4395], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [17, 18, 19]
# output of possible_action_values tensor([0.4430, 0.4402, 0.4416], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [47, 48, 49, 50]
# output of possible_action_values tensor([0.4413, 0.4448, 0.4432, 0.4410], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [14, 15, 16]
# output of possible_action_values tensor([0.4405, 0.4429, 0.4411], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [20, 21, 22]
# output of possible_action_values tensor([0.4429, 0.4371, 0.4388], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [51, 52, 53, 54]
# output of possible_action_values tensor([0.4428, 0.4447, 0.4406, 0.4407], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [17, 18, 19]
# output of possible_action_values tensor([0.4430, 0.4402, 0.4416], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [23, 24, 25]
# output of possible_action_values tensor([0.4401, 0.4363, 0.4366], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [55, 56, 57, 58]
# output of possible_action_values tensor([0.4432, 0.4422, 0.4385, 0.4394], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [20, 21, 22]
# output of possible_action_values tensor([0.4429, 0.4371, 0.4388], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [26, 27]
# output of possible_action_values tensor([0.4336, 0.4321], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [59, 60, 61, 62]
# output of possible_action_values tensor([0.4406, 0.4392, 0.4377, 0.4379], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [23, 24, 25]
# output of possible_action_values tensor([0.4401, 0.4363, 0.4366], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [63, 64, 65]
# output of possible_action_values tensor([0.4366, 0.4363, 0.4358], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [0, 1]
# output of possible_action_values tensor([0.4331, 0.4333], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [31, 32, 33, 34]
# output of possible_action_values tensor([0.4388, 0.4387, 0.4385, 0.4383], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [66, 67, 68]
# output of possible_action_values tensor([0.4367, 0.4365, 0.4374], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [28, 29, 30]
# output of possible_action_values tensor([0.4371, 0.4363, 0.4368], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [2, 3, 4]
# output of possible_action_values tensor([0.4371, 0.4369, 0.4363], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [35, 36, 37, 38]
# output of possible_action_values tensor([0.4382, 0.4390, 0.4394, 0.4381], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [69, 70, 71, 72]
# output of possible_action_values tensor([0.4389, 0.4382, 0.4381, 0.4388], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [31, 32, 33, 34]
# output of possible_action_values tensor([0.4388, 0.4387, 0.4385, 0.4383], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [5, 6, 7]
# output of possible_action_values tensor([0.4366, 0.4385, 0.4367], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [39, 40, 41, 42]
# output of possible_action_values tensor([0.4385, 0.4406, 0.4413, 0.4389], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [73, 74, 75, 76]
# output of possible_action_values tensor([0.4383, 0.4385, 0.4389, 0.4385], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [35, 36, 37, 38]
# output of possible_action_values tensor([0.4382, 0.4390, 0.4394, 0.4381], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [8, 9, 10]
# output of possible_action_values tensor([0.4369, 0.4405, 0.4375], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [43, 44, 45, 46]
# output of possible_action_values tensor([0.4394, 0.4425, 0.4428, 0.4395], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [77, 78, 79, 80]
# output of possible_action_values tensor([0.4381, 0.4393, 0.4395, 0.4383], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [39, 40, 41, 42]
# output of possible_action_values tensor([0.4385, 0.4406, 0.4413, 0.4389], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [11, 12, 13]
# output of possible_action_values tensor([0.4385, 0.4430, 0.4395], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [47, 48, 49, 50]
# output of possible_action_values tensor([0.4413, 0.4448, 0.4432, 0.4410], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [81, 82, 83, 84]
# output of possible_action_values tensor([0.4389, 0.4413, 0.4410, 0.4389], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [43, 44, 45, 46]
# output of possible_action_values tensor([0.4394, 0.4425, 0.4428, 0.4395], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [14, 15, 16]
# output of possible_action_values tensor([0.4405, 0.4429, 0.4411], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [51, 52, 53, 54]
# output of possible_action_values tensor([0.4428, 0.4447, 0.4406, 0.4407], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [85, 86, 87, 88]
# output of possible_action_values tensor([0.4395, 0.4428, 0.4407, 0.4391], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [47, 48, 49, 50]
# output of possible_action_values tensor([0.4413, 0.4448, 0.4432, 0.4410], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [17, 18, 19]
# output of possible_action_values tensor([0.4430, 0.4402, 0.4416], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [55, 56, 57, 58]
# output of possible_action_values tensor([0.4432, 0.4422, 0.4385, 0.4394], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [89, 90, 91, 92]
# output of possible_action_values tensor([0.4410, 0.4432, 0.4394, 0.4395], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [51, 52, 53, 54]
# output of possible_action_values tensor([0.4428, 0.4447, 0.4406, 0.4407], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [20, 21, 22]
# output of possible_action_values tensor([0.4429, 0.4371, 0.4388], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [59, 60, 61, 62]
# output of possible_action_values tensor([0.4406, 0.4392, 0.4377, 0.4379], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [93, 94, 95, 96]
# output of possible_action_values tensor([0.4406, 0.4406, 0.4379, 0.4383], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [55, 56, 57, 58]
# output of possible_action_values tensor([0.4432, 0.4422, 0.4385, 0.4394], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [23, 24, 25]
# output of possible_action_values tensor([0.4401, 0.4363, 0.4366], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [63, 64, 65]
# output of possible_action_values tensor([0.4366, 0.4363, 0.4358], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [97, 98, 99, 100]
# output of possible_action_values tensor([0.4394, 0.4385, 0.4380, 0.4383], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [59, 60, 61, 62]
# output of possible_action_values tensor([0.4406, 0.4392, 0.4377, 0.4379], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [26, 27]
# output of possible_action_values tensor([0.4336, 0.4321], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [101, 102, 103]
# output of possible_action_values tensor([0.4360, 0.4355, 0.4364], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [28, 29, 30]
# output of possible_action_values tensor([0.4371, 0.4363, 0.4368], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [69, 70, 71, 72]
# output of possible_action_values tensor([0.4389, 0.4382, 0.4381, 0.4388], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [104, 105, 106]
# output of possible_action_values tensor([0.4368, 0.4370, 0.4376], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [66, 67, 68]
# output of possible_action_values tensor([0.4367, 0.4365, 0.4374], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [31, 32, 33, 34]
# output of possible_action_values tensor([0.4388, 0.4387, 0.4385, 0.4383], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [73, 74, 75, 76]
# output of possible_action_values tensor([0.4383, 0.4385, 0.4389, 0.4385], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [107, 108, 109, 110]
# output of possible_action_values tensor([0.4395, 0.4384, 0.4385, 0.4388], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [69, 70, 71, 72]
# output of possible_action_values tensor([0.4389, 0.4382, 0.4381, 0.4388], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [35, 36, 37, 38]
# output of possible_action_values tensor([0.4382, 0.4390, 0.4394, 0.4381], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [77, 78, 79, 80]
# output of possible_action_values tensor([0.4381, 0.4393, 0.4395, 0.4383], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [111, 112, 113, 114]
# output of possible_action_values tensor([0.4388, 0.4381, 0.4383, 0.4381], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [73, 74, 75, 76]
# output of possible_action_values tensor([0.4383, 0.4385, 0.4389, 0.4385], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [39, 40, 41, 42]
# output of possible_action_values tensor([0.4385, 0.4406, 0.4413, 0.4389], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [81, 82, 83, 84]
# output of possible_action_values tensor([0.4389, 0.4413, 0.4410, 0.4389], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [115, 116, 117, 118]
# output of possible_action_values tensor([0.4385, 0.4389, 0.4389, 0.4380], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [77, 78, 79, 80]
# output of possible_action_values tensor([0.4381, 0.4393, 0.4395, 0.4383], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [43, 44, 45, 46]
# output of possible_action_values tensor([0.4394, 0.4425, 0.4428, 0.4395], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [85, 86, 87, 88]
# output of possible_action_values tensor([0.4395, 0.4428, 0.4407, 0.4391], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [119, 120, 121, 122]
# output of possible_action_values tensor([0.4383, 0.4396, 0.4391, 0.4374], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [81, 82, 83, 84]
# output of possible_action_values tensor([0.4389, 0.4413, 0.4410, 0.4389], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [47, 48, 49, 50]
# output of possible_action_values tensor([0.4413, 0.4448, 0.4432, 0.4410], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [89, 90, 91, 92]
# output of possible_action_values tensor([0.4410, 0.4432, 0.4394, 0.4395], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [123, 124, 125, 126]
# output of possible_action_values tensor([0.4389, 0.4410, 0.4395, 0.4379], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [85, 86, 87, 88]
# output of possible_action_values tensor([0.4395, 0.4428, 0.4407, 0.4391], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [51, 52, 53, 54]
# output of possible_action_values tensor([0.4428, 0.4447, 0.4406, 0.4407], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [93, 94, 95, 96]
# output of possible_action_values tensor([0.4406, 0.4406, 0.4379, 0.4383], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [127, 128, 129, 130]
# output of possible_action_values tensor([0.4391, 0.4406, 0.4384, 0.4374], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [89, 90, 91, 92]
# output of possible_action_values tensor([0.4410, 0.4432, 0.4394, 0.4395], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [55, 56, 57, 58]
# output of possible_action_values tensor([0.4432, 0.4422, 0.4385, 0.4394], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [97, 98, 99, 100]
# output of possible_action_values tensor([0.4394, 0.4385, 0.4380, 0.4383], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [131, 132, 133, 134]
# output of possible_action_values tensor([0.4395, 0.4394, 0.4383, 0.4379], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [93, 94, 95, 96]
# output of possible_action_values tensor([0.4406, 0.4406, 0.4379, 0.4383], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [59, 60, 61, 62]
# output of possible_action_values tensor([0.4406, 0.4392, 0.4377, 0.4379], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [101, 102, 103]
# output of possible_action_values tensor([0.4360, 0.4355, 0.4364], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [135, 136, 137, 138]
# output of possible_action_values tensor([0.4383, 0.4379, 0.4386, 0.4380], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [97, 98, 99, 100]
# output of possible_action_values tensor([0.4394, 0.4385, 0.4380, 0.4383], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [63, 64, 65]
# output of possible_action_values tensor([0.4366, 0.4363, 0.4358], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [139, 140, 141]
# output of possible_action_values tensor([0.4365, 0.4358, 0.4370], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [66, 67, 68]
# output of possible_action_values tensor([0.4367, 0.4365, 0.4374], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [107, 108, 109, 110]
# output of possible_action_values tensor([0.4395, 0.4384, 0.4385, 0.4388], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [142, 143, 144]
# output of possible_action_values tensor([0.4374, 0.4370, 0.4374], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [104, 105, 106]
# output of possible_action_values tensor([0.4368, 0.4370, 0.4376], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [69, 70, 71, 72]
# output of possible_action_values tensor([0.4389, 0.4382, 0.4381, 0.4388], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [111, 112, 113, 114]
# output of possible_action_values tensor([0.4388, 0.4381, 0.4383, 0.4381], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [145, 146, 147, 148]
# output of possible_action_values tensor([0.4397, 0.4388, 0.4381, 0.4382], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [107, 108, 109, 110]
# output of possible_action_values tensor([0.4395, 0.4384, 0.4385, 0.4388], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [73, 74, 75, 76]
# output of possible_action_values tensor([0.4383, 0.4385, 0.4389, 0.4385], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [115, 116, 117, 118]
# output of possible_action_values tensor([0.4385, 0.4389, 0.4389, 0.4380], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [149, 150, 151, 152]
# output of possible_action_values tensor([0.4388, 0.4385, 0.4380, 0.4374], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [111, 112, 113, 114]
# output of possible_action_values tensor([0.4388, 0.4381, 0.4383, 0.4381], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [77, 78, 79, 80]
# output of possible_action_values tensor([0.4381, 0.4393, 0.4395, 0.4383], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [119, 120, 121, 122]
# output of possible_action_values tensor([0.4383, 0.4396, 0.4391, 0.4374], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [153, 154, 155, 156]
# output of possible_action_values tensor([0.4381, 0.4383, 0.4374, 0.4367], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [115, 116, 117, 118]
# output of possible_action_values tensor([0.4385, 0.4389, 0.4389, 0.4380], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [81, 82, 83, 84]
# output of possible_action_values tensor([0.4389, 0.4413, 0.4410, 0.4389], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [123, 124, 125, 126]
# output of possible_action_values tensor([0.4389, 0.4410, 0.4395, 0.4379], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [157, 158, 159, 160]
# output of possible_action_values tensor([0.4380, 0.4389, 0.4379, 0.4365], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [119, 120, 121, 122]
# output of possible_action_values tensor([0.4383, 0.4396, 0.4391, 0.4374], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [85, 86, 87, 88]
# output of possible_action_values tensor([0.4395, 0.4428, 0.4407, 0.4391], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [127, 128, 129, 130]
# output of possible_action_values tensor([0.4391, 0.4406, 0.4384, 0.4374], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [161, 162, 163, 164]
# output of possible_action_values tensor([0.4374, 0.4391, 0.4374, 0.4359], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [123, 124, 125, 126]
# output of possible_action_values tensor([0.4389, 0.4410, 0.4395, 0.4379], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [89, 90, 91, 92]
# output of possible_action_values tensor([0.4410, 0.4432, 0.4394, 0.4395], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [131, 132, 133, 134]
# output of possible_action_values tensor([0.4395, 0.4394, 0.4383, 0.4379], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [165, 166, 167, 168]
# output of possible_action_values tensor([0.4379, 0.4395, 0.4379, 0.4367], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [127, 128, 129, 130]
# output of possible_action_values tensor([0.4391, 0.4406, 0.4384, 0.4374], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [93, 94, 95, 96]
# output of possible_action_values tensor([0.4406, 0.4406, 0.4379, 0.4383], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [135, 136, 137, 138]
# output of possible_action_values tensor([0.4383, 0.4379, 0.4386, 0.4380], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [169, 170, 171, 172]
# output of possible_action_values tensor([0.4374, 0.4383, 0.4381, 0.4370], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [131, 132, 133, 134]
# output of possible_action_values tensor([0.4395, 0.4394, 0.4383, 0.4379], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [97, 98, 99, 100]
# output of possible_action_values tensor([0.4394, 0.4385, 0.4380, 0.4383], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [139, 140, 141]
# output of possible_action_values tensor([0.4365, 0.4358, 0.4370], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [173, 174, 175, 176]
# output of possible_action_values tensor([0.4379, 0.4383, 0.4390, 0.4382], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [135, 136, 137, 138]
# output of possible_action_values tensor([0.4383, 0.4379, 0.4386, 0.4380], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [101, 102, 103]
# output of possible_action_values tensor([0.4360, 0.4355, 0.4364], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [177, 178, 179]
# output of possible_action_values tensor([0.4362, 0.4365, 0.4369], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [104, 105, 106]
# output of possible_action_values tensor([0.4368, 0.4370, 0.4376], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [145, 146, 147, 148]
# output of possible_action_values tensor([0.4397, 0.4388, 0.4381, 0.4382], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [180, 181, 182]
# output of possible_action_values tensor([0.4376, 0.4363, 0.4374], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [142, 143, 144]
# output of possible_action_values tensor([0.4374, 0.4370, 0.4374], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [107, 108, 109, 110]
# output of possible_action_values tensor([0.4395, 0.4384, 0.4385, 0.4388], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [149, 150, 151, 152]
# output of possible_action_values tensor([0.4388, 0.4385, 0.4380, 0.4374], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [183, 184, 185, 186]
# output of possible_action_values tensor([0.4395, 0.4388, 0.4374, 0.4379], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [145, 146, 147, 148]
# output of possible_action_values tensor([0.4397, 0.4388, 0.4381, 0.4382], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [111, 112, 113, 114]
# output of possible_action_values tensor([0.4388, 0.4381, 0.4383, 0.4381], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [153, 154, 155, 156]
# output of possible_action_values tensor([0.4381, 0.4383, 0.4374, 0.4367], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [187, 188, 189, 190]
# output of possible_action_values tensor([0.4382, 0.4381, 0.4367, 0.4363], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [149, 150, 151, 152]
# output of possible_action_values tensor([0.4388, 0.4385, 0.4380, 0.4374], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [115, 116, 117, 118]
# output of possible_action_values tensor([0.4385, 0.4389, 0.4389, 0.4380], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [157, 158, 159, 160]
# output of possible_action_values tensor([0.4380, 0.4389, 0.4379, 0.4365], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [191, 192, 193, 194]
# output of possible_action_values tensor([0.4374, 0.4380, 0.4366, 0.4361], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [153, 154, 155, 156]
# output of possible_action_values tensor([0.4381, 0.4383, 0.4374, 0.4367], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [119, 120, 121, 122]
# output of possible_action_values tensor([0.4383, 0.4396, 0.4391, 0.4374], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [161, 162, 163, 164]
# output of possible_action_values tensor([0.4374, 0.4391, 0.4374, 0.4359], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [195, 196, 197, 198]
# output of possible_action_values tensor([0.4367, 0.4374, 0.4359, 0.4356], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [157, 158, 159, 160]
# output of possible_action_values tensor([0.4380, 0.4389, 0.4379, 0.4365], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [123, 124, 125, 126]
# output of possible_action_values tensor([0.4389, 0.4410, 0.4395, 0.4379], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [165, 166, 167, 168]
# output of possible_action_values tensor([0.4379, 0.4395, 0.4379, 0.4367], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [199, 200, 201, 202]
# output of possible_action_values tensor([0.4365, 0.4379, 0.4367, 0.4360], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [161, 162, 163, 164]
# output of possible_action_values tensor([0.4374, 0.4391, 0.4374, 0.4359], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [127, 128, 129, 130]
# output of possible_action_values tensor([0.4391, 0.4406, 0.4384, 0.4374], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [169, 170, 171, 172]
# output of possible_action_values tensor([0.4374, 0.4383, 0.4381, 0.4370], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [203, 204, 205, 206]
# output of possible_action_values tensor([0.4359, 0.4374, 0.4370, 0.4362], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [165, 166, 167, 168]
# output of possible_action_values tensor([0.4379, 0.4395, 0.4379, 0.4367], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [131, 132, 133, 134]
# output of possible_action_values tensor([0.4395, 0.4394, 0.4383, 0.4379], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [173, 174, 175, 176]
# output of possible_action_values tensor([0.4379, 0.4383, 0.4390, 0.4382], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [207, 208, 209, 210]
# output of possible_action_values tensor([0.4367, 0.4379, 0.4382, 0.4377], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [169, 170, 171, 172]
# output of possible_action_values tensor([0.4374, 0.4383, 0.4381, 0.4370], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [135, 136, 137, 138]
# output of possible_action_values tensor([0.4383, 0.4379, 0.4386, 0.4380], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [177, 178, 179]
# output of possible_action_values tensor([0.4362, 0.4365, 0.4369], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [211, 212, 213, 214]
# output of possible_action_values tensor([0.4370, 0.4381, 0.4391, 0.4389], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [173, 174, 175, 176]
# output of possible_action_values tensor([0.4379, 0.4383, 0.4390, 0.4382], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [139, 140, 141]
# output of possible_action_values tensor([0.4365, 0.4358, 0.4370], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [215, 216, 217]
# output of possible_action_values tensor([0.4363, 0.4369, 0.4376], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [142, 143, 144]
# output of possible_action_values tensor([0.4374, 0.4370, 0.4374], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [183, 184, 185, 186]
# output of possible_action_values tensor([0.4395, 0.4388, 0.4374, 0.4379], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [218, 219, 220]
# output of possible_action_values tensor([0.4374, 0.4360, 0.4374], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [180, 181, 182]
# output of possible_action_values tensor([0.4376, 0.4363, 0.4374], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [145, 146, 147, 148]
# output of possible_action_values tensor([0.4397, 0.4388, 0.4381, 0.4382], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [187, 188, 189, 190]
# output of possible_action_values tensor([0.4382, 0.4381, 0.4367, 0.4363], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [221, 222, 223, 224]
# output of possible_action_values tensor([0.4395, 0.4382, 0.4363, 0.4375], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [183, 184, 185, 186]
# output of possible_action_values tensor([0.4395, 0.4388, 0.4374, 0.4379], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [149, 150, 151, 152]
# output of possible_action_values tensor([0.4388, 0.4385, 0.4380, 0.4374], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [191, 192, 193, 194]
# output of possible_action_values tensor([0.4374, 0.4380, 0.4366, 0.4361], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [225, 226, 227, 228]
# output of possible_action_values tensor([0.4379, 0.4374, 0.4361, 0.4361], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [187, 188, 189, 190]
# output of possible_action_values tensor([0.4382, 0.4381, 0.4367, 0.4363], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [153, 154, 155, 156]
# output of possible_action_values tensor([0.4381, 0.4383, 0.4374, 0.4367], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [195, 196, 197, 198]
# output of possible_action_values tensor([0.4367, 0.4374, 0.4359, 0.4356], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [229, 230, 231, 232]
# output of possible_action_values tensor([0.4363, 0.4367, 0.4355, 0.4354], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [191, 192, 193, 194]
# output of possible_action_values tensor([0.4374, 0.4380, 0.4366, 0.4361], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [157, 158, 159, 160]
# output of possible_action_values tensor([0.4380, 0.4389, 0.4379, 0.4365], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [199, 200, 201, 202]
# output of possible_action_values tensor([0.4365, 0.4379, 0.4367, 0.4360], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [233, 234, 235, 236]
# output of possible_action_values tensor([0.4361, 0.4365, 0.4360, 0.4361], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [195, 196, 197, 198]
# output of possible_action_values tensor([0.4367, 0.4374, 0.4359, 0.4356], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [161, 162, 163, 164]
# output of possible_action_values tensor([0.4374, 0.4391, 0.4374, 0.4359], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [203, 204, 205, 206]
# output of possible_action_values tensor([0.4359, 0.4374, 0.4370, 0.4362], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [237, 238, 239, 240]
# output of possible_action_values tensor([0.4355, 0.4359, 0.4362, 0.4363], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [199, 200, 201, 202]
# output of possible_action_values tensor([0.4365, 0.4379, 0.4367, 0.4360], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [165, 166, 167, 168]
# output of possible_action_values tensor([0.4379, 0.4395, 0.4379, 0.4367], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [207, 208, 209, 210]
# output of possible_action_values tensor([0.4367, 0.4379, 0.4382, 0.4377], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [241, 242, 243, 244]
# output of possible_action_values tensor([0.4360, 0.4367, 0.4377, 0.4373], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [203, 204, 205, 206]
# output of possible_action_values tensor([0.4359, 0.4374, 0.4370, 0.4362], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [169, 170, 171, 172]
# output of possible_action_values tensor([0.4374, 0.4383, 0.4381, 0.4370], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [211, 212, 213, 214]
# output of possible_action_values tensor([0.4370, 0.4381, 0.4391, 0.4389], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [245, 246, 247, 248]
# output of possible_action_values tensor([0.4362, 0.4370, 0.4389, 0.4389], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [207, 208, 209, 210]
# output of possible_action_values tensor([0.4367, 0.4379, 0.4382, 0.4377], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [173, 174, 175, 176]
# output of possible_action_values tensor([0.4379, 0.4383, 0.4390, 0.4382], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [215, 216, 217]
# output of possible_action_values tensor([0.4363, 0.4369, 0.4376], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [249, 250, 251, 252]
# output of possible_action_values tensor([0.4377, 0.4382, 0.4396, 0.4403], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [211, 212, 213, 214]
# output of possible_action_values tensor([0.4370, 0.4381, 0.4391, 0.4389], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [177, 178, 179]
# output of possible_action_values tensor([0.4362, 0.4365, 0.4369], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [253, 254, 255]
# output of possible_action_values tensor([0.4370, 0.4369, 0.4389], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [180, 181, 182]
# output of possible_action_values tensor([0.4376, 0.4363, 0.4374], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [221, 222, 223, 224]
# output of possible_action_values tensor([0.4395, 0.4382, 0.4363, 0.4375], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [256, 257, 258]
# output of possible_action_values tensor([0.4374, 0.4356, 0.4366], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [218, 219, 220]
# output of possible_action_values tensor([0.4374, 0.4360, 0.4374], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [183, 184, 185, 186]
# output of possible_action_values tensor([0.4395, 0.4388, 0.4374, 0.4379], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [225, 226, 227, 228]
# output of possible_action_values tensor([0.4379, 0.4374, 0.4361, 0.4361], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [259, 260, 261, 262]
# output of possible_action_values tensor([0.4394, 0.4379, 0.4361, 0.4372], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [221, 222, 223, 224]
# output of possible_action_values tensor([0.4395, 0.4382, 0.4363, 0.4375], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [187, 188, 189, 190]
# output of possible_action_values tensor([0.4382, 0.4381, 0.4367, 0.4363], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [229, 230, 231, 232]
# output of possible_action_values tensor([0.4363, 0.4367, 0.4355, 0.4354], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [263, 264, 265, 266]
# output of possible_action_values tensor([0.4375, 0.4363, 0.4354, 0.4356], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [225, 226, 227, 228]
# output of possible_action_values tensor([0.4379, 0.4374, 0.4361, 0.4361], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [191, 192, 193, 194]
# output of possible_action_values tensor([0.4374, 0.4380, 0.4366, 0.4361], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [233, 234, 235, 236]
# output of possible_action_values tensor([0.4361, 0.4365, 0.4360, 0.4361], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [267, 268, 269, 270]
# output of possible_action_values tensor([0.4361, 0.4361, 0.4361, 0.4357], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [229, 230, 231, 232]
# output of possible_action_values tensor([0.4363, 0.4367, 0.4355, 0.4354], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [195, 196, 197, 198]
# output of possible_action_values tensor([0.4367, 0.4374, 0.4359, 0.4356], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [237, 238, 239, 240]
# output of possible_action_values tensor([0.4355, 0.4359, 0.4362, 0.4363], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [271, 272, 273, 274]
# output of possible_action_values tensor([0.4354, 0.4355, 0.4363, 0.4362], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [233, 234, 235, 236]
# output of possible_action_values tensor([0.4361, 0.4365, 0.4360, 0.4361], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [199, 200, 201, 202]
# output of possible_action_values tensor([0.4365, 0.4379, 0.4367, 0.4360], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [241, 242, 243, 244]
# output of possible_action_values tensor([0.4360, 0.4367, 0.4377, 0.4373], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [275, 276, 277, 278]
# output of possible_action_values tensor([0.4361, 0.4360, 0.4373, 0.4373], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [237, 238, 239, 240]
# output of possible_action_values tensor([0.4355, 0.4359, 0.4362, 0.4363], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [203, 204, 205, 206]
# output of possible_action_values tensor([0.4359, 0.4374, 0.4370, 0.4362], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [245, 246, 247, 248]
# output of possible_action_values tensor([0.4362, 0.4370, 0.4389, 0.4389], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [279, 280, 281, 282]
# output of possible_action_values tensor([0.4363, 0.4362, 0.4389, 0.4380], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [241, 242, 243, 244]
# output of possible_action_values tensor([0.4360, 0.4367, 0.4377, 0.4373], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [207, 208, 209, 210]
# output of possible_action_values tensor([0.4367, 0.4379, 0.4382, 0.4377], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [249, 250, 251, 252]
# output of possible_action_values tensor([0.4377, 0.4382, 0.4396, 0.4403], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [283, 284, 285, 286]
# output of possible_action_values tensor([0.4373, 0.4377, 0.4403, 0.4398], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [245, 246, 247, 248]
# output of possible_action_values tensor([0.4362, 0.4370, 0.4389, 0.4389], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [211, 212, 213, 214]
# output of possible_action_values tensor([0.4370, 0.4381, 0.4391, 0.4389], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [253, 254, 255]
# output of possible_action_values tensor([0.4370, 0.4369, 0.4389], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [287, 288, 289, 290]
# output of possible_action_values tensor([0.4389, 0.4389, 0.4409, 0.4415], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [249, 250, 251, 252]
# output of possible_action_values tensor([0.4377, 0.4382, 0.4396, 0.4403], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [215, 216, 217]
# output of possible_action_values tensor([0.4363, 0.4369, 0.4376], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [291, 292, 293]
# output of possible_action_values tensor([0.4385, 0.4375, 0.4397], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [218, 219, 220]
# output of possible_action_values tensor([0.4374, 0.4360, 0.4374], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [259, 260, 261, 262]
# output of possible_action_values tensor([0.4394, 0.4379, 0.4361, 0.4372], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [294, 295, 296]
# output of possible_action_values tensor([0.4374, 0.4353, 0.4363], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [256, 257, 258]
# output of possible_action_values tensor([0.4374, 0.4356, 0.4366], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [221, 222, 223, 224]
# output of possible_action_values tensor([0.4395, 0.4382, 0.4363, 0.4375], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [263, 264, 265, 266]
# output of possible_action_values tensor([0.4375, 0.4363, 0.4354, 0.4356], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [297, 298, 299, 300]
# output of possible_action_values tensor([0.4387, 0.4375, 0.4356, 0.4367], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [259, 260, 261, 262]
# output of possible_action_values tensor([0.4394, 0.4379, 0.4361, 0.4372], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [225, 226, 227, 228]
# output of possible_action_values tensor([0.4379, 0.4374, 0.4361, 0.4361], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [267, 268, 269, 270]
# output of possible_action_values tensor([0.4361, 0.4361, 0.4361, 0.4357], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [301, 302, 303, 304]
# output of possible_action_values tensor([0.4372, 0.4361, 0.4357, 0.4358], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [263, 264, 265, 266]
# output of possible_action_values tensor([0.4375, 0.4363, 0.4354, 0.4356], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [229, 230, 231, 232]
# output of possible_action_values tensor([0.4363, 0.4367, 0.4355, 0.4354], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [271, 272, 273, 274]
# output of possible_action_values tensor([0.4354, 0.4355, 0.4363, 0.4362], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [305, 306, 307, 308]
# output of possible_action_values tensor([0.4356, 0.4354, 0.4362, 0.4357], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [267, 268, 269, 270]
# output of possible_action_values tensor([0.4361, 0.4361, 0.4361, 0.4357], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [233, 234, 235, 236]
# output of possible_action_values tensor([0.4361, 0.4365, 0.4360, 0.4361], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [275, 276, 277, 278]
# output of possible_action_values tensor([0.4361, 0.4360, 0.4373, 0.4373], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [309, 310, 311, 312]
# output of possible_action_values tensor([0.4357, 0.4361, 0.4373, 0.4368], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [271, 272, 273, 274]
# output of possible_action_values tensor([0.4354, 0.4355, 0.4363, 0.4362], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [237, 238, 239, 240]
# output of possible_action_values tensor([0.4355, 0.4359, 0.4362, 0.4363], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [279, 280, 281, 282]
# output of possible_action_values tensor([0.4363, 0.4362, 0.4389, 0.4380], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [313, 314, 315, 316]
# output of possible_action_values tensor([0.4362, 0.4363, 0.4380, 0.4375], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [275, 276, 277, 278]
# output of possible_action_values tensor([0.4361, 0.4360, 0.4373, 0.4373], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [241, 242, 243, 244]
# output of possible_action_values tensor([0.4360, 0.4367, 0.4377, 0.4373], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [283, 284, 285, 286]
# output of possible_action_values tensor([0.4373, 0.4377, 0.4403, 0.4398], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [317, 318, 319, 320]
# output of possible_action_values tensor([0.4373, 0.4373, 0.4398, 0.4383], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [279, 280, 281, 282]
# output of possible_action_values tensor([0.4363, 0.4362, 0.4389, 0.4380], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [245, 246, 247, 248]
# output of possible_action_values tensor([0.4362, 0.4370, 0.4389, 0.4389], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [287, 288, 289, 290]
# output of possible_action_values tensor([0.4389, 0.4389, 0.4409, 0.4415], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [321, 322, 323, 324]
# output of possible_action_values tensor([0.4380, 0.4389, 0.4415, 0.4399], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [283, 284, 285, 286]
# output of possible_action_values tensor([0.4373, 0.4377, 0.4403, 0.4398], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [249, 250, 251, 252]
# output of possible_action_values tensor([0.4377, 0.4382, 0.4396, 0.4403], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [291, 292, 293]
# output of possible_action_values tensor([0.4385, 0.4375, 0.4397], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [325, 326, 327, 328]
# output of possible_action_values tensor([0.4398, 0.4403, 0.4417, 0.4413], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [287, 288, 289, 290]
# output of possible_action_values tensor([0.4389, 0.4389, 0.4409, 0.4415], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [253, 254, 255]
# output of possible_action_values tensor([0.4370, 0.4369, 0.4389], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [329, 330, 331]
# output of possible_action_values tensor([0.4398, 0.4389, 0.4403], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [256, 257, 258]
# output of possible_action_values tensor([0.4374, 0.4356, 0.4366], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [297, 298, 299, 300]
# output of possible_action_values tensor([0.4387, 0.4375, 0.4356, 0.4367], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [332, 333]
# output of possible_action_values tensor([0.4332, 0.4309], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [294, 295, 296]
# output of possible_action_values tensor([0.4374, 0.4353, 0.4363], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [259, 260, 261, 262]
# output of possible_action_values tensor([0.4394, 0.4379, 0.4361, 0.4372], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [301, 302, 303, 304]
# output of possible_action_values tensor([0.4372, 0.4361, 0.4357, 0.4358], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [334, 335, 336]
# output of possible_action_values tensor([0.4363, 0.4353, 0.4336], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [297, 298, 299, 300]
# output of possible_action_values tensor([0.4387, 0.4375, 0.4356, 0.4367], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [263, 264, 265, 266]
# output of possible_action_values tensor([0.4375, 0.4363, 0.4354, 0.4356], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [305, 306, 307, 308]
# output of possible_action_values tensor([0.4356, 0.4354, 0.4362, 0.4357], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [337, 338, 339]
# output of possible_action_values tensor([0.4345, 0.4337, 0.4334], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [301, 302, 303, 304]
# output of possible_action_values tensor([0.4372, 0.4361, 0.4357, 0.4358], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [267, 268, 269, 270]
# output of possible_action_values tensor([0.4361, 0.4361, 0.4361, 0.4357], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [309, 310, 311, 312]
# output of possible_action_values tensor([0.4357, 0.4361, 0.4373, 0.4368], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [340, 341, 342]
# output of possible_action_values tensor([0.4336, 0.4337, 0.4346], device='cuda:0', grad_fn=<SqueezeBackward0>)
# ...
# out_nodes [145, 146, 147, 148]
# output of possible_action_values tensor([0.4412, 0.4413, 0.4442, 0.4449], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [180, 181, 182]
# output of possible_action_values tensor([0.4391, 0.4432, 0.4460], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [142, 143, 144]
# output of possible_action_values tensor([0.4388, 0.4407, 0.4425], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [107, 108, 109, 110]
# output of possible_action_values tensor([0.4409, 0.4444, 0.4427, 0.4425], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [149, 150, 151, 152]
# output of possible_action_values tensor([0.4425, 0.4427, 0.4470, 0.4454], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [183, 184, 185, 186]
# output of possible_action_values tensor([0.4446, 0.4425, 0.4454, 0.4466], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [145, 146, 147, 148]
# output of possible_action_values tensor([0.4412, 0.4413, 0.4442, 0.4449], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [111, 112, 113, 114]
# output of possible_action_values tensor([0.4413, 0.4440, 0.4454, 0.4442], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [153, 154, 155, 156]
# output of possible_action_values tensor([0.4442, 0.4454, 0.4500, 0.4468], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [187, 188, 189, 190]
# output of possible_action_values tensor([0.4449, 0.4442, 0.4468, 0.4445], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [149, 150, 151, 152]
# output of possible_action_values tensor([0.4425, 0.4427, 0.4470, 0.4454], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [115, 116, 117, 118]
# output of possible_action_values tensor([0.4427, 0.4462, 0.4502, 0.4470], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [157, 158, 159, 160]
# output of possible_action_values tensor([0.4470, 0.4502, 0.4532, 0.4505], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [191, 192, 193, 194]
# output of possible_action_values tensor([0.4454, 0.4470, 0.4505, 0.4456], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [153, 154, 155, 156]
# output of possible_action_values tensor([0.4442, 0.4454, 0.4500, 0.4468], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [119, 120, 121, 122]
# output of possible_action_values tensor([0.4454, 0.4505, 0.4527, 0.4500], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [161, 162, 163, 164]
# output of possible_action_values tensor([0.4500, 0.4527, 0.4529, 0.4518], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [195, 196, 197, 198]
# output of possible_action_values tensor([0.4468, 0.4500, 0.4518, 0.4485], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [157, 158, 159, 160]
# output of possible_action_values tensor([0.4470, 0.4502, 0.4532, 0.4505], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [123, 124, 125, 126]
# output of possible_action_values tensor([0.4502, 0.4546, 0.4544, 0.4533], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [165, 166, 167, 168]
# output of possible_action_values tensor([0.4532, 0.4545, 0.4529, 0.4531], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [199, 200, 201, 202]
# output of possible_action_values tensor([0.4505, 0.4532, 0.4530, 0.4513], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [161, 162, 163, 164]
# output of possible_action_values tensor([0.4500, 0.4527, 0.4529, 0.4518], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [127, 128, 129, 130]
# output of possible_action_values tensor([0.4527, 0.4540, 0.4523, 0.4529], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [169, 170, 171, 172]
# output of possible_action_values tensor([0.4529, 0.4522, 0.4500, 0.4510], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [203, 204, 205, 206]
# output of possible_action_values tensor([0.4518, 0.4529, 0.4510, 0.4507], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [165, 166, 167, 168]
# output of possible_action_values tensor([0.4532, 0.4545, 0.4529, 0.4531], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [131, 132, 133, 134]
# output of possible_action_values tensor([0.4545, 0.4534, 0.4512, 0.4530], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [173, 174, 175, 176]
# output of possible_action_values tensor([0.4530, 0.4512, 0.4489, 0.4486], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [207, 208, 209, 210]
# output of possible_action_values tensor([0.4531, 0.4530, 0.4486, 0.4503], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [169, 170, 171, 172]
# output of possible_action_values tensor([0.4529, 0.4522, 0.4500, 0.4510], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [135, 136, 137, 138]
# output of possible_action_values tensor([0.4522, 0.4511, 0.4498, 0.4500], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [177, 178, 179]
# output of possible_action_values tensor([0.4485, 0.4481, 0.4449], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [211, 212, 213, 214]
# output of possible_action_values tensor([0.4510, 0.4500, 0.4468, 0.4484], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [173, 174, 175, 176]
# output of possible_action_values tensor([0.4530, 0.4512, 0.4489, 0.4486], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [139, 140, 141]
# output of possible_action_values tensor([0.4497, 0.4491, 0.4472], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [215, 216, 217]
# output of possible_action_values tensor([0.4470, 0.4471, 0.4447], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [142, 143, 144]
# output of possible_action_values tensor([0.4388, 0.4407, 0.4425], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [183, 184, 185, 186]
# output of possible_action_values tensor([0.4446, 0.4425, 0.4454, 0.4466], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [218, 219, 220]
# output of possible_action_values tensor([0.4426, 0.4450, 0.4465], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [180, 181, 182]
# output of possible_action_values tensor([0.4391, 0.4432, 0.4460], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [145, 146, 147, 148]
# output of possible_action_values tensor([0.4412, 0.4413, 0.4442, 0.4449], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [187, 188, 189, 190]
# output of possible_action_values tensor([0.4449, 0.4442, 0.4468, 0.4445], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [221, 222, 223, 224]
# output of possible_action_values tensor([0.4479, 0.4449, 0.4445, 0.4460], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [183, 184, 185, 186]
# output of possible_action_values tensor([0.4446, 0.4425, 0.4454, 0.4466], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [149, 150, 151, 152]
# output of possible_action_values tensor([0.4425, 0.4427, 0.4470, 0.4454], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [191, 192, 193, 194]
# output of possible_action_values tensor([0.4454, 0.4470, 0.4505, 0.4456], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [225, 226, 227, 228]
# output of possible_action_values tensor([0.4466, 0.4454, 0.4456, 0.4436], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [187, 188, 189, 190]
# output of possible_action_values tensor([0.4449, 0.4442, 0.4468, 0.4445], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [153, 154, 155, 156]
# output of possible_action_values tensor([0.4442, 0.4454, 0.4500, 0.4468], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [195, 196, 197, 198]
# output of possible_action_values tensor([0.4468, 0.4500, 0.4518, 0.4485], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [229, 230, 231, 232]
# output of possible_action_values tensor([0.4445, 0.4467, 0.4485, 0.4445], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [191, 192, 193, 194]
# output of possible_action_values tensor([0.4454, 0.4470, 0.4505, 0.4456], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [157, 158, 159, 160]
# output of possible_action_values tensor([0.4470, 0.4502, 0.4532, 0.4505], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [199, 200, 201, 202]
# output of possible_action_values tensor([0.4505, 0.4532, 0.4530, 0.4513], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [233, 234, 235, 236]
# output of possible_action_values tensor([0.4456, 0.4505, 0.4513, 0.4478], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [195, 196, 197, 198]
# output of possible_action_values tensor([0.4468, 0.4500, 0.4518, 0.4485], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [161, 162, 163, 164]
# output of possible_action_values tensor([0.4500, 0.4527, 0.4529, 0.4518], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [203, 204, 205, 206]
# output of possible_action_values tensor([0.4518, 0.4529, 0.4510, 0.4507], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [237, 238, 239, 240]
# output of possible_action_values tensor([0.4485, 0.4518, 0.4507, 0.4484], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [199, 200, 201, 202]
# output of possible_action_values tensor([0.4505, 0.4532, 0.4530, 0.4513], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [165, 166, 167, 168]
# output of possible_action_values tensor([0.4532, 0.4545, 0.4529, 0.4531], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [207, 208, 209, 210]
# output of possible_action_values tensor([0.4531, 0.4530, 0.4486, 0.4503], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [241, 242, 243, 244]
# output of possible_action_values tensor([0.4513, 0.4531, 0.4503, 0.4481], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [203, 204, 205, 206]
# output of possible_action_values tensor([0.4518, 0.4529, 0.4510, 0.4507], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [169, 170, 171, 172]
# output of possible_action_values tensor([0.4529, 0.4522, 0.4500, 0.4510], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [211, 212, 213, 214]
# output of possible_action_values tensor([0.4510, 0.4500, 0.4468, 0.4484], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [245, 246, 247, 248]
# output of possible_action_values tensor([0.4507, 0.4510, 0.4484, 0.4493], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [207, 208, 209, 210]
# output of possible_action_values tensor([0.4531, 0.4530, 0.4486, 0.4503], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [173, 174, 175, 176]
# output of possible_action_values tensor([0.4530, 0.4512, 0.4489, 0.4486], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [215, 216, 217]
# output of possible_action_values tensor([0.4470, 0.4471, 0.4447], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [249, 250, 251, 252]
# output of possible_action_values tensor([0.4503, 0.4486, 0.4465, 0.4493], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [211, 212, 213, 214]
# output of possible_action_values tensor([0.4510, 0.4500, 0.4468, 0.4484], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [177, 178, 179]
# output of possible_action_values tensor([0.4485, 0.4481, 0.4449], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [253, 254, 255]
# output of possible_action_values tensor([0.4468, 0.4449, 0.4473], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [180, 181, 182]
# output of possible_action_values tensor([0.4391, 0.4432, 0.4460], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [221, 222, 223, 224]
# output of possible_action_values tensor([0.4479, 0.4449, 0.4445, 0.4460], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [256, 257, 258]
# output of possible_action_values tensor([0.4462, 0.4444, 0.4429], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [218, 219, 220]
# output of possible_action_values tensor([0.4426, 0.4450, 0.4465], device='cuda:0', grad_fn=<SqueezeBackward0>)
# out_nodes [183, 184, 185, 186]
# output of possible_action_values tensor([0.4446, 0.4425, 0.4454, 0.4466], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [225, 226, 227, 228]
# output of possible_action_values tensor([0.4466, 0.4454, 0.4456, 0.4436], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# out_nodes [259, 260, 261, 262]
# output of possible_action_values
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_24687/2614251714.py in <module>
#      21         print("GCN-DQN")
#      22         dqn_agent_gcn = DQNAgent(city, model_type='gcn', policy_pow=policy_pow,strategy=strategy)
# ---> 23         train(city, dqn_agent_gcn, epochs = TRAIN_EPOCH, time_steps=TRAIN_TIME_STEPS, verbose=False)
#      24         with torch.no_grad():
#      25             eval_and_write(city, dqn_agent_gcn, call_coeff)
#
# ~/TaxiSimulatorOnGraph/main.py in train(city, agent, epochs, time_steps, write_log, log_save_folder, save_model, model_save_folder, verbose, epsilon_min, **kwargs)
#      78             city.seed = seed
#      79             # get policy from s_t
# ---> 80             policy = agent.get_policy(observations)
#      81             # apply policy to city and get observation/number of assigned order/missed order.
#      82             next_observations, assigned, missed = city.step(policy)
#
# ~/TaxiSimulatorOnGraph/agents.py in get_policy(self, observations, use_target_model, to_numpy)
#     278             else:
#     279                 possible_action_values = q_values[out_nodes].squeeze()
# --> 280                 print("output of possible_action_values", possible_action_values)
#     281                 policy_v = self.get_policy_from_action_values(possible_action_values)
#     282                 if to_numpy:
#
# ~/miniconda3/envs/roadnetwork/lib/python3.7/site-packages/torch/_tensor.py in __repr__(self, tensor_contents)
#     336                                          tensor_contents=tensor_contents)
#     337         # All strings are unicode in Python 3.
# --> 338         return torch._tensor_str._str(self, tensor_contents=tensor_contents)
#     339
#     340     def backward(self, gradient=None, retain_graph=None, create_graph=False, inputs=None):
#
# ~/miniconda3/envs/roadnetwork/lib/python3.7/site-packages/torch/_tensor_str.py in _str(self, tensor_contents)
#     479 def _str(self, *, tensor_contents=None):
#     480     with torch.no_grad():
# --> 481         return _str_intern(self, tensor_contents=tensor_contents)
#
# ~/miniconda3/envs/roadnetwork/lib/python3.7/site-packages/torch/_tensor_str.py in _str_intern(inp, tensor_contents)
#     445                         tensor_str = _tensor_str(self.to_dense(), indent)
#     446                     else:
# --> 447                         tensor_str = _tensor_str(self, indent)
#     448
#     449     if self.layout != torch.strided:
#
# ~/miniconda3/envs/roadnetwork/lib/python3.7/site-packages/torch/_tensor_str.py in _tensor_str(self, indent)
#     268         return _tensor_str_with_formatter(self, indent, summarize, real_formatter, imag_formatter)
#     269     else:
# --> 270         formatter = _Formatter(get_summarized_data(self) if summarize else self)
#     271         return _tensor_str_with_formatter(self, indent, summarize, formatter)
#     272
#
# ~/miniconda3/envs/roadnetwork/lib/python3.7/site-packages/torch/_tensor_str.py in __init__(self, tensor)
#     132                 # Check if scientific representation should be used.
#     133                 if nonzero_finite_max / nonzero_finite_min > 1000.\
# --> 134                         or nonzero_finite_max > 1.e8\
#     135                         or nonzero_finite_min < 1.e-4:
#     136                     self.sci_mode = True
#
# KeyboardInterrupt:
